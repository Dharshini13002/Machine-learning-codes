# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharshini13002/Machine-learning-codes/blob/main/5)Naivebayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace 'your_file.xlsx' with your actual filename
df = pd.read_excel('/content/drive/MyDrive/Mobile_Games.xlsx')

# Display the first few rows
df.head()
# Out:
#   Name     Age GENDER Daily I use to play Mobile games  \
# 0    A   10-15      M                            agree
# 1    B   16-25      F                          netural
# 2    C   26-35      M                            agree
# 3    D   36-45      M                   strongly agree
# 4    E   46-50      F                            agree
#
#   Daily 2 to 4 hrs I play I use to play Mobile games to have fun  \
# 0          strongly agree                         strongly agree
# 1                   agree                                  agree
# 2                   agree                                  agree
# 3                   agree                         strongly agree
# 4                   agree                                  agree
#
#   I use to play Mobile games to kill my time  \
# 0                         strongly dis agree
# 1                             strongly agree
# 2                             strongly agree
# 3                         strongly dis agree
# ...

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_features=6,
    n_classes=3,
    n_samples=800,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y, marker="*");

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %%
from sklearn.naive_bayes import GaussianNB

# Build a Gaussian Classifier
model = GaussianNB()

# Model training
model.fit(X_train, y_train)

# Predict Output
predicted = model.predict([X_test[6]])

print("Actual Value:", y_test[6])
print("Predicted Value:", predicted[0])
# Out:
# Actual Value: 0
# Predicted Value: 0

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
)

y_pred = model.predict(X_test)
accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.8484848484848485
# F1 Score: 0.8491119695890328

# %%
labels = [0,1,2]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %%
import pandas as pd


df = pd.read_excel('/content/drive/MyDrive/Mobile_Games.xlsx')
df.head()
# Out:
#   Name     Age GENDER Daily I use to play Mobile games  \
# 0    A   10-15      M                            agree
# 1    B   16-25      F                          netural
# 2    C   26-35      M                            agree
# 3    D   36-45      M                   strongly agree
# 4    E   46-50      F                            agree
#
#   Daily 2 to 4 hrs I play I use to play Mobile games to have fun  \
# 0          strongly agree                         strongly agree
# 1                   agree                                  agree
# 2                   agree                                  agree
# 3                   agree                         strongly agree
# 4                   agree                                  agree
#
#   I use to play Mobile games to kill my time  \
# 0                         strongly dis agree
# 1                             strongly agree
# 2                             strongly agree
# 3                         strongly dis agree
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 16 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Name                                             24 non-null     object
#  1   Age                                              24 non-null     object
#  2   GENDER                                           24 non-null     object
#  3   Daily I use to play Mobile games                 24 non-null     object
#  4   Daily 2 to 4 hrs I play                          24 non-null     object
#  5   I use to play Mobile games to have fun           24 non-null     object
#  6   I use to play Mobile games to kill my time       24 non-null     object
#  7   I use to play Mobile games to escape real world  24 non-null     object
#  8   I use to play Mobile games for strees relif      24 non-null     object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Age', hue='GENDER')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Optional: to prevent label cut-off
plt.show()

# %%
pre_df = pd.get_dummies(df,columns=['Age'],drop_first=True)
pre_df.head()
# Out:
#   Name GENDER Daily I use to play Mobile games Daily 2 to 4 hrs I play  \
# 0    A      M                            agree          strongly agree
# 1    B      F                          netural                   agree
# 2    C      M                            agree                   agree
# 3    D      M                   strongly agree                   agree
# 4    E      F                            agree                   agree
#
#   I use to play Mobile games to have fun  \
# 0                         strongly agree
# 1                                  agree
# 2                                  agree
# 3                         strongly agree
# 4                                  agree
#
#   I use to play Mobile games to kill my time  \
# 0                         strongly dis agree
# 1                             strongly agree
# 2                             strongly agree
# 3                         strongly dis agree
# 4                             strongly agree
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Select only numerical columns for X and drop the 'Unnamed' columns
X = pre_df.select_dtypes(include=['number']).drop(columns=['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'])
y = pre_df['Daily I use to play Mobile games']

# Label encode y
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.33, random_state=125
)

# %%
# Label encode the 'GENDER' column only
y = LabelEncoder().fit_transform(pre_df['GENDER'])  # y will be 1D

# %%
from sklearn.model_selection import train_test_split

# Assuming X is already preprocessed (imputed, numeric, etc.)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %%
print(y.shape)          # should be (num_samples,)
print(y_train.shape)    # should also be 1D
# Out:
# (24,)
# (16,)

# %%
y_train = y_train.ravel()

# %%
print(X_train.shape)   # Should be (samples, features)
print(y_train.shape)   # Should be (samples,)
# Out:
# (16, 8)
# (16,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# Separate features and target
X = pre_df.drop(columns=['GENDER'])  # All features
y = pre_df['GENDER']                 # Target

# One-hot encode categorical features
X_encoded = pd.get_dummies(X, drop_first=True)

# Impute missing values with mean (you can also try 'most_frequent' or 'median')
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X_encoded)

# Encode the target
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y_encoded, test_size=0.33, random_state=125)

# Train GaussianNB model
model = GaussianNB()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.375
# F1 Score: 0.40476190476190477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.20      0.50      0.29         2
#            1       0.67      0.33      0.44         6
#
#     accuracy                           0.38         8
#    macro avg       0.43      0.42      0.37         8
# weighted avg       0.55      0.38      0.40         8

# %%
# prompt: i want a code to add a record

# Example new record as a dictionary
new_record_data = {
    'Timestamp': '12/1/2024 12:00:00', # Example value, adjust based on your data
    'Age': '21-25',                     # Example value
    'GENDER': 'Male',                   # Example value
    # Add all other columns from your original DataFrame with example values
    # Ensure keys match your DataFrame column names
    'Daily I use to play Mobile games': '2-3 hours', # Example value
    'Average amount of money spent on mobile games per month': 'Less than $10', # Example
    'Do you find ads in games disruptive?': 'Yes', # Example
    'How likely are you to make in-game purchases?': 'Unlikely', # Example
    'What prevents you from spending more money on mobile games?': 'Cost', # Example
    'How do you usually discover new mobile games?': 'App store', # Example
    'How important is the graphics quality in a mobile game?': 'Important', # Example
    'How important is the storyline in a mobile game?': 'Important', # Example
    'How important is the social interaction in a mobile game?': 'Important', # Example
    'Unnamed: 11': None, # Handle potential unnamed columns appropriately
    'Unnamed: 12': None,
    'Unnamed: 13': None,
    'Unnamed: 14': None
}

# Create a new DataFrame from the record data
new_record_df = pd.DataFrame([new_record_data])

# Concatenate the new record DataFrame with the existing DataFrame
# Be careful if you modify the original df often.
# A better approach might be to reload the dataframe from the file
# or manage changes in a structured way if you are making many additions.
df = pd.concat([df, new_record_df], ignore_index=True)

# Display the last few rows to see the added record
print("\nDataFrame after adding a new record:")
print(df.tail())
# Out:
# DataFrame after adding a new record:
#    Name    Age GENDER Daily I use to play Mobile games  \
# 20    V  46-50      F                            agree
# 21    W  36-45      F                            agree
# 22    X  26-35      M                   strongly agree
# 23    Y  26-35      M                   strongly agree
# 24  NaN  21-25   Male                        2-3 hours
#
#    Daily 2 to 4 hrs I play I use to play Mobile games to have fun  \
# 20                   agree                                  agree
# 21                   agree                                  agree
# 22          strongly agree                         strongly agree
# 23          strongly agree                         strongly agree
# 24                     NaN                                    NaN
#
#    I use to play Mobile games to kill my time  \
# 20                             strongly agree
# 21                             strongly agree
# 22                                  dis agree
# ...

# %%
import pandas as pd

# Replace 'your_file.xlsx' with your actual filename
df = pd.read_excel('/content/drive/MyDrive/Mobile_Games.xlsx')

# Display the first few rows
df.head()
# Out:
#   Name     Age GENDER Daily I use to play Mobile games  \
# 0    A   10-15      M                            agree
# 1    B   16-25      F                          netural
# 2    C   26-35      M                            agree
# 3    D   36-45      M                   strongly agree
# 4    E   46-50      F                            agree
#
#   Daily 2 to 4 hrs I play I use to play Mobile games to have fun  \
# 0          strongly agree                         strongly agree
# 1                   agree                                  agree
# 2                   agree                                  agree
# 3                   agree                         strongly agree
# 4                   agree                                  agree
#
#   I use to play Mobile games to kill my time  \
# 0                         strongly dis agree
# 1                             strongly agree
# 2                             strongly agree
# 3                         strongly dis agree
# ...

# %%
# prompt: Using dataframe df: bar chart

import altair as alt

# Create a bar chart using Altair
# The x-axis represents the unique values in the 'Age' column
# The y-axis represents the count of occurrences for each age group
chart = alt.Chart(df).mark_bar().encode(
    x='Age:O', # Use ':O' to treat 'Age' as an ordinal variable for categorical display
    y='count()' # Count the occurrences of each age group
)

# Display the chart
chart
# Out:
# alt.Chart(...)

# %%
# prompt: Using dataframe df: pie chart

import altair as alt
# Calculate the counts of each gender
gender_counts = df['GENDER'].value_counts().reset_index()
gender_counts.columns = ['GENDER', 'count']
# Create the pie chart
chart = alt.Chart(gender_counts).mark_arc().encode(
    # Encode the count as the theta (angle) of the arc
    theta=alt.Theta(field="count", type="quantitative"),
    # Encode the gender as the color
    color=alt.Color(field="GENDER", type="nominal")
)
chart
# Out:
# alt.Chart(...)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1svTVMVHx8GcQIcezyAdRGNcgckA-mPOANQTIABz9M7U/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1svTVMVHx8GcQIcezyAdRGNcgckA-mPOANQTIABz9M7U/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# prompt: write  another 5 rows of data  using write function to sit on the record

# List of 5 new records as dictionaries
new_records_data = [
    {
        'Timestamp': '12/1/2024 12:01:00',
        'Age': '16-20',
        'GENDER': 'Female',
        'Daily I use to play Mobile games': '1-2 hours',
        'Average amount of money spent on mobile games per month': '$10-$20',
        'Do you find ads in games disruptive?': 'No',
        'How likely are you to make in-game purchases?': 'Likely',
        'What prevents you from spending more money on mobile games?': 'Not interested',
        'How do you usually discover new mobile games?': 'Social media',
        'How important is the graphics quality in a mobile game?': 'Not important',
        'How important is the storyline in a mobile game?': 'Less important',
        'How important is the social interaction in a mobile game?': 'Very important',
        'Unnamed: 11': None,
        'Unnamed: 12': None,
        'Unnamed: 13': None,
        'Unnamed: 14': None
    },
    {
        'Timestamp': '12/1/2024 12:02:00',
        'Age': '26-30',
        'GENDER': 'Male',
        'Daily I use to play Mobile games': '3-4 hours',
        'Average amount of money spent on mobile games per month': 'More than $20',
        'Do you find ads in games disruptive?': 'Yes',
        'How likely are you to make in-game purchases?': 'Very likely',
        'What prevents you from spending more money on mobile games?': 'None',
        'How do you usually discover new mobile games?': 'Friends/Family',
        'How important is the graphics quality in a mobile game?': 'Very important',
        'How important is the storyline in a mobile game?': 'Important',
        'How important is the social interaction in a mobile game?': 'Less important',
        'Unnamed: 11': None,
        'Unnamed: 12': None,
        'Unnamed: 13': None,
        'Unnamed: 14': None
    },
    {
        'Timestamp': '12/1/2024 12:03:00',
        'Age': '31-40',
        'GENDER': 'Female',
        'Daily I use to play Mobile games': 'Less than 1 hour',
        'Average amount of money spent on mobile games per month': 'Less than $10',
        'Do you find ads in games disruptive?': 'Maybe',
        'How likely are you to make in-game purchases?': 'Unlikely',
        'What prevents you from spending more money on mobile games?': 'Cost',
        'How do you usually discover new mobile games?': 'App store',
        'How important is the graphics quality in a mobile game?': 'Important',
        'How important is the storyline in a mobile game?': 'Very important',
        'How important is the social interaction in a mobile game?': 'Not important',
        'Unnamed: 11': None,
        'Unnamed: 12': None,
        'Unnamed: 13': None,
        'Unnamed: 14': None
    },
    {
        'Timestamp': '12/1/2024 12:04:00',
        'Age': '21-25',
        'GENDER': 'Other', # Example for handling other genders
        'Daily I use to play Mobile games': '2-3 hours',
        'Average amount of money spent on mobile games per month': '$10-$20',
        'Do you find ads in games disruptive?': 'Yes',
        'How likely are you to make in-game purchases?': 'Neutral',
        'What prevents you from spending more money on mobile games?': 'Lack of content',
        'How do you usually discover new mobile games?': 'Online reviews',
        'How important is the graphics quality in a mobile game?': 'Very important',
        'How important is the storyline in a mobile game?': 'Important',
        'How important is the social interaction in a mobile game?': 'Important',
        'Unnamed: 11': None,
        'Unnamed: 12': None,
        'Unnamed: 13': None,
        'Unnamed: 14': None
    },
    {
        'Timestamp': '12/1/2024 12:05:00',
        'Age': '16-20',
        'GENDER': 'Male',
        'Daily I use to play Mobile games': '4+ hours',
        'Average amount of money spent on mobile games per month': 'More than $20',
        'Do you find ads in games disruptive?': 'No',
        'How likely are you to make in-game purchases?': 'Very likely',
        'What prevents you from spending more money on mobile games?': 'None',
        'How do you usually discover new mobile games?': 'Social media',
        'How important is the graphics quality in a mobile game?': 'Very important',
        'How important is the storyline in a mobile game?': 'Less important',
        'How important is the social interaction in a mobile game?': 'Very important',
        'Unnamed: 11': None,
        'Unnamed: 12': None,
        'Unnamed: 13': None,
        'Unnamed: 14': None
    }
]

# Create a new DataFrame from the list of record data
new_records_df = pd.DataFrame(new_records_data)

# Concatenate the new records DataFrame with the existing DataFrame
df = pd.concat([df, new_records_df], ignore_index=True)

# Display the last few rows to see the added records
print("\nDataFrame after adding 5 new records:")
print(df.tail(7)) # Display last 7 rows to show the original added record and the new ones
# Out:
# DataFrame after adding 5 new records:
#    Name    Age  GENDER Daily I use to play Mobile games  \
# 32  NaN  41-50    Male                        1-2 hours
# 33  NaN  26-30  Female                        2-3 hours
# 34  NaN  16-20  Female                        1-2 hours
# 35  NaN  26-30    Male                        3-4 hours
# 36  NaN  31-40  Female                 Less than 1 hour
# 37  NaN  21-25   Other                        2-3 hours
# 38  NaN  16-20    Male                         4+ hours
#
#    Daily 2 to 4 hrs I play I use to play Mobile games to have fun  \
# 32                     NaN                                    NaN
# 33                     NaN                                    NaN
# 34                     NaN                                    NaN
# 35                     NaN                                    NaN
# 36                     NaN                                    NaN
# 37                     NaN                                    NaN
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/13AJvK2_duB4G41mFrVtLH488ohED6DjagLSdN30kB_s/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/13AJvK2_duB4G41mFrVtLH488ohED6DjagLSdN30kB_s/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
